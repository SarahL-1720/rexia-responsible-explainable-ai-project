# %% [markdown]
# # REXIA - project

# %% [markdown]
# ## 0. Import & setup

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Tabular data

# %% [markdown]
# ## Data analysis

# %%
df = pd.read_csv("../RH_dataset.csv")
df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23857 entries, 0 to 23856
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                      --------------  -----
#  0   Famille d'emploi;Dernière promotion (mois);Dernière augmentation (mois);Début de contrat (années);Ancienneté groupe (années);Etablissement;Âge (années);Parent;Niveau hiérarchique;Salaire (Euros);Statut marital;Véhicule;matricule;label  23857 non-null  object
# dtypes: object(1)
# memory usage: 186.5+ KB

# %%
num_cols = df.select_dtypes(include=[np.number]).columns
cat_cols = df.select_dtypes(include=[str]).columns
assert len(num_cols) + len(cat_cols) == df.shape[1], "Some columns are not categorized correctly."

# %% [markdown]
# ## Analysis of potential bias and sensitive data

# %% [markdown]
# privacy

# %% [markdown]
# # Textual data

# %% [markdown]
# # Image data
